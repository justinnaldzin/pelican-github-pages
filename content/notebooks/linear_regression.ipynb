# %%
# pip3 install sklearn scipy pandas

import numpy as np
import pandas as pd
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.io import output_notebook, show
from sklearn.linear_model import LinearRegression
 
output_notebook()
 
# Define data
x_1 = np.linspace(0,10,11)
x_0 = np.ones(len(x_1))
y = 4 * x_1 + np.random.normal(0, 5, len(x_1))
data = pd.DataFrame(np.column_stack([x_0,x_1,y]), columns=['x_0','x_1','y'])
 
# Define the model by explicitely saying that our data contains an intercept term
reg = LinearRegression(fit_intercept=False)
 
# Fit the data
reg.fit(data[['x_0','x_1']], data['y'])
 
# Evaluate the model on the given x
y_pred = reg.predict(data[['x_0','x_1']])
 
# Plot comparison
p = figure()
p.circle(x_1, y, legend='observation')
p.line(x_1, y_pred, legend='model', color='red')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d1cd6e5f-c713-4a3f-8366-e6b0e1c47165">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bc556d31-8e4c-4410-9004-bcfc24f3d5c6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bc556d31-8e4c-4410-9004-bcfc24f3d5c6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bc556d31-8e4c-4410-9004-bcfc24f3d5c6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bc556d31-8e4c-4410-9004-bcfc24f3d5c6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"16389350-364f-4746-9c33-8a212c0a73b1":{"roots":{"references":[{"attributes":{"callback":null},"id":"c5221e90-8fe4-45b3-b64f-c6fb844ffd98","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"94adf909-8725-4e62-ad95-8a1e5e4eacfa","type":"Line"},{"attributes":{"label":{"value":"model"},"renderers":[{"id":"63070e1b-ffeb-4cb1-94e3-ca59dc0d5cdf","type":"GlyphRenderer"}]},"id":"c34bf399-4108-4149-8ce8-f117a8afec79","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBAAAAAAAAAIkAAAAAAAAAkQA==","dtype":"float64","shape":[11]},"y":{"__ndarray__":"hBsC4mwhEEDVV7FO3fQNQKiEzNPDvCZAlGmo3gOwNUAKxwzcBnY2QKxGgxQdhDNAoe49Y1pLOkCXHo/WlqU9QLGQ6dAPljtAT2/fgoWnQECAFlgLNjdFQA==","dtype":"float64","shape":[11]}}},"id":"f243a732-5d96-4d98-ac4b-92208c95b1ca","type":"ColumnDataSource"},{"attributes":{},"id":"28c54933-746d-4811-a0cd-d0dcc7c3414a","type":"ToolEvents"},{"attributes":{"plot":{"id":"e0d2f21a-87c5-468a-bd2b-fb884d917e3a","subtype":"Figure","type":"Plot"}},"id":"36f63206-5c5f-4b91-94f7-afaa73b02c84","type":"SaveTool"},{"attributes":{"below":[{"id":"ce4d19fc-56ad-4660-a403-6691cdc9fd80","type":"LinearAxis"}],"left":[{"id":"f78fac4b-e854-4277-8f27-f74780f0aa32","type":"LinearAxis"}],"renderers":[{"id":"ce4d19fc-56ad-4660-a403-6691cdc9fd80","type":"LinearAxis"},{"id":"9e10ce15-399d-44a9-844f-668b5bab8fc5","type":"Grid"},{"id":"f78fac4b-e854-4277-8f27-f74780f0aa32","type":"LinearAxis"},{"id":"521995b8-ed50-4bfd-8519-27dc614ca1fa","type":"Grid"},{"id":"7771dcd6-97da-4f33-a4a3-06066cf171fe","type":"BoxAnnotation"},{"id":"1383e5c7-5ab1-4820-b636-36db377e9f05","type":"Legend"},{"id":"36ae65d6-76fc-4575-8ed5-014da68c5c8b","type":"GlyphRenderer"},{"id":"63070e1b-ffeb-4cb1-94e3-ca59dc0d5cdf","type":"GlyphRenderer"}],"title":{"id":"8210042b-f150-4c17-af48-124ea201f6b1","type":"Title"},"tool_events":{"id":"28c54933-746d-4811-a0cd-d0dcc7c3414a","type":"ToolEvents"},"toolbar":{"id":"c858aadd-e690-4ee1-9339-2a9bb40e58a9","type":"Toolbar"},"x_range":{"id":"340081c2-54c9-4384-9f3e-680390b60ba4","type":"DataRange1d"},"y_range":{"id":"c5221e90-8fe4-45b3-b64f-c6fb844ffd98","type":"DataRange1d"}},"id":"e0d2f21a-87c5-468a-bd2b-fb884d917e3a","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"e0d2f21a-87c5-468a-bd2b-fb884d917e3a","subtype":"Figure","type":"Plot"},"ticker":{"id":"07edac7c-1b5c-4aac-826e-1d3f4591f5c8","type":"BasicTicker"}},"id":"521995b8-ed50-4bfd-8519-27dc614ca1fa","type":"Grid"},{"attributes":{"callback":null},"id":"340081c2-54c9-4384-9f3e-680390b60ba4","type":"DataRange1d"},{"attributes":{"data_source":{"id":"f243a732-5d96-4d98-ac4b-92208c95b1ca","type":"ColumnDataSource"},"glyph":{"id":"960b9f1e-fb3d-4c90-8ecb-8a5a1afe2352","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"696bb569-679f-49d3-b593-da9fe655110a","type":"Circle"},"selection_glyph":null},"id":"36ae65d6-76fc-4575-8ed5-014da68c5c8b","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"8210042b-f150-4c17-af48-124ea201f6b1","type":"Title"},{"attributes":{},"id":"07edac7c-1b5c-4aac-826e-1d3f4591f5c8","type":"BasicTicker"},{"attributes":{"overlay":{"id":"7771dcd6-97da-4f33-a4a3-06066cf171fe","type":"BoxAnnotation"},"plot":{"id":"e0d2f21a-87c5-468a-bd2b-fb884d917e3a","subtype":"Figure","type":"Plot"}},"id":"6f0d657d-4841-48f0-8b86-99f40c51de79","type":"BoxZoomTool"},{"attributes":{},"id":"4f80f4ff-e947-40a4-9fe5-d359daef41b5","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4bc2a5b4-488e-422b-8622-55ae3a03f66c","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0fca0260-80c6-4bfb-a792-36b1db956fc0","type":"PanTool"},{"id":"bfc09fb4-33ab-45a0-b970-a557cf5 ...
